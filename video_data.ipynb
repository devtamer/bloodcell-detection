# %%
import cv2
import os
import numpy as np
from google.colab import drive
# !rm frame*
# !rm -rf sample_data

# vidcap = cv2.VideoCapture('videos/50x50 micrometer  channel D  0.06ul per min  40x  without dextran 01.mp4')
# success,image = vidcap.read()
# count = 0
# success = True
# while success and count < 20:
#   success,image = vidcap.read()
#   cv2.imwrite( "frame%d.jpg" % count, image)     # save frame as JPEG file 
#   np.save(os.path.join('50x50 micrometer  channel D  0.06ul per min  40x  without dextran 01/', 'data'), image)
#   print('Read a new frame: ', success)

#   count += 1
# Out:
# rm: cannot remove 'frame*': No such file or directory

# %% [markdown]
# # New Section
